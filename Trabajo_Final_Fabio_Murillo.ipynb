# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiomurillo/StructuraliaTrabajoFinal/blob/main/Trabajo_Final_Fabio_Murillo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io

# %%
url2015 = "https://raw.githubusercontent.com/fabiomurillo/StructuraliaTrabajoFinal/main/PJCROD_POLICIALES_V1-2015.csv"
url2016 = "https://raw.githubusercontent.com/fabiomurillo/StructuraliaTrabajoFinal/main/PJCROD_POLICIALES_V1-2016.csv"
url2017 = "https://raw.githubusercontent.com/fabiomurillo/StructuraliaTrabajoFinal/main/PJCROD_POLICIALES_V1-2017.csv"
url2018 = "https://raw.githubusercontent.com/fabiomurillo/StructuraliaTrabajoFinal/main/PJCROD_POLICIALES_V1-2018.csv"
url2019 = "https://raw.githubusercontent.com/fabiomurillo/StructuraliaTrabajoFinal/main/PJCROD_POLICIALES_V1-2019.csv"
url2020 = "https://raw.githubusercontent.com/fabiomurillo/StructuraliaTrabajoFinal/main/PJCROD_POLICIALES_V1-2020.csv"
url2021 = "https://raw.githubusercontent.com/fabiomurillo/StructuraliaTrabajoFinal/main/PJCROD_POLICIALES_V1-2021.csv"
url2022 = "https://raw.githubusercontent.com/fabiomurillo/StructuraliaTrabajoFinal/main/PJCROD_POLICIALES_V1-2022.csv"

dataset2015  = pd.read_csv(url2015,encoding='latin-1')
dataset2016  = pd.read_csv(url2016,encoding='latin-1')
dataset2017  = pd.read_csv(url2017,encoding='latin-1')
dataset2018  = pd.read_csv(url2018,encoding='latin-1')
dataset2019  = pd.read_csv(url2019,encoding='latin-1')
dataset2020  = pd.read_csv(url2020,encoding='latin-1')
dataset2021  = pd.read_csv(url2021,encoding='latin-1')
dataset2022  = pd.read_csv(url2022,encoding='latin-1')


dataset2015.head()
# Out:
#    Delito      SubDelito       Fecha      Victima  \
# 0  ASALTO  ARMA DE FUEGO  2015-12-05     VIVIENDA
# 1  ASALTO  ARMA DE FUEGO  2015-12-05  EDIFICACION
# 2  ASALTO  ARMA DE FUEGO  2015-12-05     VIVIENDA
# 3  ASALTO  ARMA DE FUEGO  2015-12-05     VIVIENDA
# 4  ASALTO  ARMA DE FUEGO  2015-12-06      PERSONA
#
#                              SubVictima           Edad  Genero Nacionalidad  \
# 0             SIN CLASIFICAR [VIVIENDA]  Mayor de edad     NaN   COSTA RICA
# 1  VIDEO CLUB/VIDEO JUEGO [EDIFICACION]    Desconocido     NaN   COSTA RICA
# 2             SIN CLASIFICAR [VIVIENDA]  Mayor de edad     NaN    NICARAGUA
# 3                  NO APLICA [VIVIENDA]  Mayor de edad     NaN     COLOMBIA
# 4                      PEATON [PERSONA]  Menor de edad     NaN   COSTA RICA
#
#     Provincia        Canton   Distrito
# 0       LIMON     SIQUIRRES    ALEGRIA
# 1    SAN JOSE        ASERRI     ASERRI
# 2       LIMON     SIQUIRRES  SIQUIRRES
# 3    SAN JOSE  DESAMPARADOS    ROSARIO
# ...
